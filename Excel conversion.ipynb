# %%
import pandas as pd

# %%
data = pd.read_excel('test.xlsx')

# %%
print(data)
# Out:
#       Scan                 Time  tank 2   tank3  tan out  205 (C)  206 (C)  \
# 0      1.0             09:51:53  42.527  41.638   41.418   42.430   42.916
# 1      2.0             09:52:23  42.652  41.678   41.764   42.736   42.778
# 2      3.0             09:52:53  42.730  41.708   42.058   42.932   42.840
# 3      4.0             09:53:23  42.802  41.745   42.250   43.065   42.940
# 4      5.0             09:53:53  42.891  41.786   42.471   43.261   43.119
# ...    ...                  ...     ...     ...      ...      ...      ...
# 1011   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1012   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1013   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1014   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1015   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
#
#       209 (C)  210 (C)  211 (C)  212 (C)  213 (C)
# ...

# %%
# 30 sec intervals la irundhadhu so naa evry 10th row yeduthaa 5 mins ku varum so adg=ha mattum yeduthukitan kaa

data = data.iloc[::10, :]
print(data)
# Out:
#       Scan                 Time  tank 2   tank3  tan out  205 (C)  206 (C)  \
# 0      1.0             09:51:53  42.527  41.638   41.418   42.430   42.916
# 10    11.0             09:56:53  43.579  42.052   43.357   44.037   43.956
# 20    21.0             10:01:53  44.870  42.628   44.617   45.364   45.179
# 30    31.0             10:06:53  46.143  43.289   45.837   46.538   46.463
# 40    41.0             10:11:53  47.350  43.992   47.069   47.787   47.822
# ...    ...                  ...     ...     ...      ...      ...      ...
# 970    NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 980    NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 990    NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1000   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
# 1010   NaN  2024-01-03 00:00:00     NaN     NaN      NaN      NaN      NaN
#
#       209 (C)  210 (C)  211 (C)  212 (C)  213 (C)
# ...

# %%
data.to_excel('5_Mins_interval.xlsx', index=False)
